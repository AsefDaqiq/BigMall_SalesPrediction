# %% [markdown]
# ### Election Data Project - Polls and Donors
#
# In this Data Project we will be looking at data from the 2012 election.
#
# In this project we will analyze two datasets. The first data set will be the results of political polls. We will analyze this aggregated poll data and answer some questions:
#
# 1.) Who was being polled and what was their party affiliation?
# 2.) Did the poll results favor Romney or Obama?
# 3.) How do undecided voters effect the poll?
# 4.) Can we account for the undecided voters?
# 5.) How did voter sentiment change over time?
# 6.) Can we see an effect in the polls from the debates?

# %%
import requests 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from io import StringIO

# %%
#url
url = "http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv"

# %%
# Use requests to get the information in text form
source = requests.get(url).text

# %%
#Using StringIO to avoid an IO error with pandas
poll_data = StringIO(source)

# %%
# converting the data into dataframe
poll_df = pd.read_csv(poll_data)

# %%
# checking the review of the data
poll_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 17 columns):
# Pollster                  586 non-null object
# Start Date                586 non-null object
# End Date                  586 non-null object
# Entry Date/Time (ET)      586 non-null object
# Number of Observations    564 non-null float64
# Population                586 non-null object
# Mode                      586 non-null object
# Obama                     586 non-null float64
# Romney                    586 non-null float64
# Undecided                 423 non-null float64
# Other                     202 non-null float64
# Pollster URL              586 non-null object
# Source URL                584 non-null object
# Partisan                  586 non-null object
# Affiliation               586 non-null object
# Question Text             0 non-null float64
# Question Iteration        586 non-null int64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 77.9+ KB

# %%
poll_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
sns.set_style(style='whitegrid')

# %%
#Ploting Affiliation through countplot
sns.countplot('Affiliation',data=poll_df)

# %% [markdown]
# Looks like we are overall relatively neutral, but still leaning towards Democratic Affiliation, it will be good to keep this in mind. Let's see if sorting by the Population hue gives us any further insight into the data.

# %%
sns.countplot('Affiliation', hue='Population', data=poll_df)

# %% [markdown]
# Looks like we have a strong showing of likely voters and Registered Voters, so the poll data should hopefully be a good reflection on the populations polled. Let's take another quick overview of the DataFrame.

# %%
poll_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
#finding the mean of the data
avg = pd.DataFrame(poll_df.mean())

# %%
avg.head()
# Out:
#                                   0
# Number of Observations  1296.679078
# Obama                     46.805461
# Romney                    44.614334
# Undecided                  6.550827
# Other                      3.376238

# %%
#removing the Number of Oberservations row
avg.drop(index='Number of Observations', axis=0, inplace=True)

# %%
avg.head()
# Out:
#                        0
# Obama          46.805461
# Romney         44.614334
# Undecided       6.550827
# Other           3.376238
# Question Text        NaN

# %%
std = pd.DataFrame(poll_df.mean())

# %%
std.head()
# Out:
#                                   0
# Number of Observations  1296.679078
# Obama                     46.805461
# Romney                    44.614334
# Undecided                  6.550827
# Other                      3.376238

# %%
#removing the row
std.drop(index='Number of Observations', inplace=True, axis=0)

# %%
std.head()
# Out:
#                        0
# Obama          46.805461
# Romney         44.614334
# Undecided       6.550827
# Other           3.376238
# Question Text        NaN

# %%
# ploting
avg.plot(yerr=std, kind='bar', legend=False)

# %%
poll_evg = pd.concat([avg, std], axis=1)

# %%
poll_evg.head()
# Out:
#                        0          0
# Obama          46.805461  46.805461
# Romney         44.614334  44.614334
# Undecided       6.550827   6.550827
# Other           3.376238   3.376238
# Question Text        NaN        NaN

# %%
poll_evg.columns= ['avg', 'std']

# %%
poll_evg.head()
# Out:
#                      avg        std
# Obama          46.805461  46.805461
# Romney         44.614334  44.614334
# Undecided       6.550827   6.550827
# Other           3.376238   3.376238
# Question Text        NaN        NaN

# %%
poll_df.plot(x='End Date', y=['Obama', 'Romney', 'Undecided', 'Other'], linestyle=" ", marker='o' )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
poll_df['difference'] = (poll_df.Obama - poll_df.Romney) / 100

# %%
poll_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                  1000.0  Likely Voters       Live Phone   47.0    47.0
# 1                   740.0  Likely Voters         Internet   49.0    47.0
# 2                   872.0  Likely Voters  Automated Phone   48.0    48.0
# 3                   712.0  Likely Voters       Live Phone   50.0    49.0
# 4                  1500.0  Likely Voters  Automated Phone   48.0    49.0
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
from datetime import datetime
from pandas import groupby
poll_df = poll_df.groupby('Start Date').mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-da951a2ed64c> in <module>()
#       1 from datetime import datetime
#       2 from pandas import groupby
# ----> 3 poll_df = poll_df.groupby('Start Date').mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     671             return self[attr]
#     672         if hasattr(self.obj, attr):
# --> 673             return self._make_wrapper(attr)
#     674
#     675         raise AttributeError("%r object has no attribute %r" %
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in _make_wrapper(self, name)
#     685                    "using the 'apply' method".format(kind, name,
#     686                                                      type(self).__name__))
# --> 687             raise AttributeError(msg)
#     688
# ...

# %%
poll_df.head()
# Out:
#                                 Pollster  Start Date    End Date  \
# 0              Politico/GWU/Battleground  2012-11-04  2012-11-05
# 1                       YouGov/Economist  2012-11-03  2012-11-05
# 2                       Gravis Marketing  2012-11-03  2012-11-05
# 3                               IBD/TIPP  2012-11-03  2012-11-05
# 4                              Rasmussen  2012-11-03  2012-11-05
# 5                   JZ Analytics/Newsmax  2012-11-03  2012-11-05
# 7                    Ipsos/Reuters (Web)  2012-11-01  2012-11-05
# 8                                    ARG  2012-11-02  2012-11-04
# 9    PPP (D-Americans United for Change)  2012-11-02  2012-11-04
# 10                                   CNN  2012-11-02  2012-11-04
# 11                              ABC/Post  2012-11-01  2012-11-04
# 12                                Gallup  2012-11-01  2012-11-04
# 13                 DailyKos/SEIU/PPP (D)  2012-11-01  2012-11-04
# ...
